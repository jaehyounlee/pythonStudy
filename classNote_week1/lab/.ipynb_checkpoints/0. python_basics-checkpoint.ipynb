# %% [markdown]
# # 0. Jupyter notebook

# %% [markdown]
# - 대화형 파이썬 웹 어플리케이션
# - 코드와 함께 문서화하기 좋음
# - 과거에는 ipython notebook이었지만, 파이썬을 포함한 여러 언어를 지원하는 Jupyter project로 범위가 확장되면서 Jupyter notebook이라 불림
# - 단축키 설명: `h`를 누르면 Jupyter notebook에서 사용할 수 있는 여러 단축키를 볼 수 있음

# %% [markdown]
# ### image를 출력할 수 있는 라이브러리

# %%
from IPython.display import Image 
Image(filename="./img/keyboard_shortcuts.png")

# %% [markdown]
# ### hello world

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# ### Scientific hello world

# %%
# %%file scientific_hello.py
import sys, math
r = float(sys.argv[1])
s = math.sin(r)
print("hello world! sin({}) = {}".format(r,s))
# Out:
# Writing scientific_hello.py

# %% [markdown]
# # 1. Introduce myself

# %% [markdown]
# 내 정보를 사용하여 아래 변수에 값을 할당해보자.

# %%
# variable assignment
name = '이재현'
age = 31
male = True
# variable types
print(type(name), type(age), type(male))
# Out:
# <class 'str'> <class 'int'> <class 'bool'>

# %% [markdown]
# `name`, `age`, `male` 변수를 입력받아 자기소개 문자열를 반환하는 `introduce` 함수의 코드를 완성해보자.

# %%
def introduce(name, age, male):
    # code here
    return print("안녕하세요 저는 " + name + "입니다. 나이는 " + age + "이고 성별은 " +  )
    
print(introduce(name, age, male))
# Out:
#   File "<ipython-input-17-b47fcd4cbbaf>", line 3
#     return print("안녕하세요 저는 " + name + "입니다. 나이는 " + age + "이고 성별은 " +  )
#                                                                        ^
# SyntaxError: invalid syntax

# %% [markdown]
# # 2. Hamlet

# %% [markdown]
# 1. 대사가 가장 많은 등장인물 top 3?
# 2. 가장 많이 등장하는 단어 top 30?

# %% [markdown]
# ## 2-1. 웹에서 연극 햄릿 원문 데이터 가져와 저장하기

# %% [markdown]
# Requests 패키지 불러오기

# %%
import requests
help(requests)
# Out:
# Help on package requests:
#
# NAME
#     requests
#
# DESCRIPTION
#     Requests HTTP library
#     ~~~~~~~~~~~~~~~~~~~~~
#
#     Requests is an HTTP library, written in Python, for human beings. Basic GET
#     usage:
#
#        >>> import requests
#        >>> r = requests.get('https://www.python.org')
#        >>> r.status_code
#        200
#        >>> 'Python is a programming language' in r.content
#        True
#
#     ... or POST:
#
#        >>> payload = dict(key1='value1', key2='value2')
#        >>> r = requests.post('http://httpbin.org/post', data=payload)
#        >>> print(r.text)
#        {
#          ...
#          "form": {
#            "key2": "value2",
#            "key1": "value1"
#          },
#          ...
#        }
#
#     The other HTTP methods are supported - see `requests.api`. Full documentation
#     is at <http://python-requests.org>.
#
#     :copyright: (c) 2016 by Kenneth Reitz.
#     :license: Apache 2.0, see LICENSE for more details.
#
# PACKAGE CONTENTS
#     _internal_utils
#     adapters
#     api
#     auth
#     certs
#     compat
#     cookies
#     exceptions
#     hooks
#     models
#     packages (package)
#     sessions
#     status_codes
#     structures
#     utils
#
# DATA
#     __build__ = 135684
#     __copyright__ = 'Copyright 2016 Kenneth Reitz'
#     __license__ = 'Apache 2.0'
#     __title__ = 'requests'
#     codes = <lookup 'status_codes'>
#
# VERSION
#     2.12.4
#
# AUTHOR
#     Kenneth Reitz
#
# FILE
#     c:\anaconda3\lib\site-packages\requests\__init__.py

# %% [markdown]
# 웹사이트에서 데이터 가져오기, 결과 살펴보기

# %%
url = 'http://shakespeare.mit.edu/hamlet/full.html'
r = requests.get(url)
print(r)
print(type(r))
print(r.headers)
print(r.encoding)
print('---')
print(r.text[:1000])
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'Date': 'Sat, 27 May 2017 02:35:08 GMT', 'Server': 'Apache/2.4.10 (Debian)', 'Last-Modified': 'Sun, 08 Jul 2012 18:23:37 GMT', 'ETag': '"52a4a-4c45598859c40-gzip"', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip', 'Cache-Control': 'max-age=15552000', 'Expires': 'Thu, 23 Nov 2017 02:35:08 GMT', 'Content-Type': 'text/html', 'X-Varnish': '34140770 34802327', 'Age': '14172', 'Via': '1.1 varnish-v4', 'Content-Length': '94303', 'Connection': 'keep-alive', 'Accept-Ranges': 'bytes'}
# ISO-8859-1
# ---
# <!DOCTYPE HTML PUBLIC "-//W3C//DTD HTML 4.0 Transitional//EN"
#  "http://www.w3.org/TR/REC-html40/loose.dtd">
#  <html>
#  <head>
#  <title>Hamlet: Entire Play
#  </title>
#  <meta http-equiv="Content-Type" content="text/html; charset=iso-8859-1">
#  <LINK rel="stylesheet" type="text/css" media="screen"
#        href="/shake.css">
#  </HEAD>
#  <body bgcolor="#ffffff" text="#000000">
#
# <table width="100%" bgcolor="#CCF6F6">
# <tr><td class="play" align="center">The Tragedy of Hamlet, Prince of Denmark
# <tr><td class="nav" align="center">
#       <a href="/Shakespeare">Shakespeare homepage</A>
#     | <A href="/hamlet/">Hamlet</A>
#     | Entire play
# </table>
#
# <H3>ACT I</h3>
# <h3>SCENE I. Elsinore. A platform before the castle.</h3>
# <p><blockquote>
# <i>FRANCISCO at his post. Enter to him BERNARDO</i>
# </blockquote>
#
# <A NAME=speech1><b>BERNARDO</b></a>
# <blockquote>
# <A NAME=1.1.1>Who's there?</A><br>
# </blockquote>
#
# <A NAME=speech2><b>FRANCISCO</b></a>
# <blockquote>
# <A NAME=1.1.2>Nay, answer me: stand, and unfold yoursel

# %% [markdown]
# 데이터 저장하기

# %%
fname = 'hamlet.txt'

# %%
with open(fname, 'w') as fout:
    fout.write(r.text)

# %% [markdown]
# 함수 형태로 정리한 코드

# %%
import requests
    
def get_data(url, fname):
    r = requests.get(url)
    with open(fname, 'w') as fout:
        fout.write(r.text)
    print('"{}" is saved.'.format(fname), end=' ')
    print('The length of data is {:,}.'.format(len(r.text)))

url = 'http://shakespeare.mit.edu/hamlet/full.html'
fname = 'hamlet.txt'
get_data(url, fname)
# Out:
# "hamlet.txt" is saved. The length of data is 338,506.

# %% [markdown]
# ## 2-2. 저장한 데이터 불러오기

# %%
with open(fname, 'r') as fin:
    data = fin.read()
    data = data.replace('A NAME', 'A ID') #for find_all method

# %% [markdown]
# You may need beautifulsoup...

# %%
data[:1000]

# %% [markdown]
# ### 2-3. beautifulsoup 사용해서 데이터 파싱하기

# %% [markdown]
# Documentation: https://cryptosan.github.io/pythondocuments/documents/beautifulsoup4/

# %%
from bs4 import BeautifulSoup as bsoup

# %%
help(bsoup)

# %% [markdown]
# 일반적인 html 문서의 구조

# %% [markdown]
# ```
# <html>
#    <head>
#       <title>
#          Example
#       </title>
#    </head>
#
#    <body>
#       <h1>Hello, world</h1>
#    </body>
# </html>
# ```

# %% [markdown]
# 이는 beautifulsoup을 사용하면 트리 형태로 파싱된다

# %%
soup = bsoup(data, 'html.parser')
type(soup)

# %%
soup.head

# %% [markdown]
# `find_all` 메서드 사용하여 파싱한 트리 탐색하기
# - 시그니처: `find_all(name, attrs, recursive, text, limit, **kwargs)`

# %%
lines = soup.find_all('blockquote')
len(lines)

# %% [markdown]
# ### 2-4. 등장인물 부분만 담은 리스트, 대사만 담은 리스트 만들기

# %% [markdown]
# #### 데이터 특징
# - 등장인물: `<A NAME=speech23><b>BERNARDO</b></a>`
# - 대사: `<A NAME=1.1.1>Who's there?</A>`
#
# #### 위에서 데이터를 불러올 때 NAME을 ID로 바꿨으니, 아래와 같은 특징을 가진다
# - 등장인물: `<A ID=speech23><b>BERNARDO</b></a>`
# - 대사: `<A ID=1.1.1>Who's there?</A>`

# %% [markdown]
# 정규표현식 모듈을 사용한 패턴 매칭 예시

# %%
import re
p_char = re.compile('speech\d*')
p_line = re.compile('\d*\.\d*\.\d*')
print(p_char.match('speech23'))
print(p_line.match('3.4.127'))

# %%
print(soup.find_all('a', id='1.1.1'))

# %%
char_list = soup.find_all(id=p_char) #등장인물 태그 리스트
line_list = soup.find_all(id=p_line) #대사 태그 리스트
print(len(char_list), len(line_list))

# %%
char_list[0], line_list[0]

# %%
type(char_list[0]), type(line_list[0])

# %% [markdown]
# 등장인물, 대사 태그에서 텍스트 부분만 남기기

# %%
char_list = [c.text for c in char_list]
line_list = [l.text for l in line_list]
print(char_list[:10])
print(line_list[:10])

# %% [markdown]
# ### 2-5. 개수 세어보기

# %% [markdown]
# 등장인물 개수 세어보기

# %%
dic = {}
for c in char_list:
    if c in dic.keys():
        dic[c] += 1
    else:
        dic[c] = 1

# %%
count_pairs = list(dic.items())
count_pairs.sort(key=lambda x: x[1], reverse=True)
for char, count in count_pairs:
    print('{:20}: {}'.format(char, count))

# %% [markdown]
# 대사에 등장하는 단어 개수를 세어보기 전에 전처리를 조금 해보자

# %%
def preprocessor(line):
    import re
    for x in '.:,?!':
        line = line.replace(x, ' ')
    p = re.compile(' +')
    line = p.sub(' ', line)
    line = line.strip()
    line = line.lower()
    return line

lines = [preprocessor(l) for l in line_list]

# %%
dic = {}
for l in lines:
    l = l.split(' ')
    for w in l:
        if w in dic.keys():
            dic[w] += 1
        else:
            dic[w] = 1

# %%
count_pairs = list(dic.items())
count_pairs.sort(key=lambda x: x[1], reverse=True)
for char, count in count_pairs:
    if count > 30:
        print('{:6}: {}'.format(char, count))

# %% [markdown]
# 참고: 파이썬 표준 라이브러리를 보다 쉽게 개수를 셀 수 있다

# %%
from collections import Counter

char_counter = Counter(char_list).items()
char_counter
